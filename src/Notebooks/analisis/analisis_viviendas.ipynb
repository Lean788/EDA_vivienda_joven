# %%
# importaciones básicas
import numpy as np
import pandas as pd

# para pintar los gráficos

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

sns.set_style('darkgrid')

# %%
v_num = pd.read_csv('../../data/clean/v_num.csv')

# %%
v_num.head(25)
# Out:
#    tipo_edif                                        regimen_ten  periodo  \
# 0      Total                                              Total     2020
# 1      Total                                              Total     2019
# 2      Total                                              Total     2018
# 3      Total                                              Total     2017
# 4      Total                                              Total     2016
# 5      Total                                              Total     2015
# 6      Total                                              Total     2014
# 7      Total                                              Total     2013
# 8      Total  Propia por compra, totalmente pagada, heredada...     2020
# 9      Total  Propia por compra, totalmente pagada, heredada...     2019
# 10     Total  Propia por compra, totalmente pagada, heredada...     2018
# 11     Total  Propia por compra, totalmente pagada, heredada...     2017
# 12     Total  Propia por compra, totalmente pagada, heredada...     2016
# 13     Total  Propia por compra, totalmente pagada, heredada...     2015
# 14     Total  Propia por compra, totalmente pagada, heredada...     2014
# 15     Total  Propia por compra, totalmente pagada, heredada...     2013
# 16     Total                        Propia con pagos pendientes     2020
# 17     Total                        Propia con pagos pendientes     2019
# 18     Total                        Propia con pagos pendientes     2018
# 19     Total                        Propia con pagos pendientes     2017
# 20     Total                        Propia con pagos pendientes     2016
# 21     Total                        Propia con pagos pendientes     2015
# 22     Total                        Propia con pagos pendientes     2014
# 23     Total                        Propia con pagos pendientes     2013
# 24     Total                                          Alquilada     2020
#
#          total
# 0   18754800.0
# 1   18625700.0
# 2   18535900.0
# 3   18472800.0
# 4   18406100.0
# 5   18346200.0
# 6   18303100.0
# 7   18217300.0
# 8    9212400.0
# 9    9153900.0
# 10   9104600.0
# 11   9005600.0
# 12   8963700.0
# 13   8975000.0
# 14   8885000.0
# 15   8893100.0
# 16   5201200.0
# 17   5031700.0
# 18   5119400.0
# 19   5169000.0
# 20   5306900.0
# 21   5199800.0
# 22   5396300.0
# 23   5485900.0
# 24   3244400.0

# %%
v_num.columns
# Out:
# Index(['tipo_edif', 'regimen_ten', 'periodo', 'total'], dtype='object')

# %%
v_num['tipo_edif'].value_counts()
# Out:
# Total                                     32
# Vivienda unifamiliar independiente        32
# Vivienda unifamiliar adosada o pareada    32
# Edificio con dos viviendas                32
# Edificio de 3 a 9 viviendas               32
# Edificio con 10 o más viviendas           32
# Edificio destinado a otros usos           32
# Name: tipo_edif, dtype: int64

# %%
v_num['regimen_ten'].value_counts()
# Out:
# Total                                                      56
# Propia por compra, totalmente pagada, heredada o donada    56
# Propia con pagos pendientes                                56
# Alquilada                                                  56
# Name: regimen_ten, dtype: int64
