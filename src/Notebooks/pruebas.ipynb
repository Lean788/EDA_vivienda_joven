# %%
# importaciones básicas
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./data/teicp040.tsv', sep='\t')
df
# Out:
#     coicop,unit,geo\time  2021M12   2022M01   2022M02   2022M03   2022M04   \
# 0            CP04,I15,AL  109.11 d  109.52 d  109.53 d  111.07 d  111.51 d
# 1            CP04,I15,AT   116.64    118.25    122.28    124.45    124.57
# 2            CP04,I15,BE   133.26    147.14    148.77    148.96    148.16
# 3            CP04,I15,BG   123.61    126.02    125.75    127.32    129.77
# 4            CP04,I15,CH   105.84    107.09    107.53    108.01    108.56
# ..                   ...       ...       ...       ...       ...       ...
# 121      CP04,PCH_M12,SI      8.5      11.1      13.8       1.1       6.4
# 122      CP04,PCH_M12,SK     -1.2      10.7      11.0      11.9      12.6
# 123      CP04,PCH_M12,TR    28.6 d    48.4 d    49.7 d    51.4 d    61.1 d
# 124      CP04,PCH_M12,US     5.6 d     6.8 d     6.7 d     7.4 d     7.8 d
# 125      CP04,PCH_M12,XK     4.8 d     8.7 d     9.0 d    15.7 d    14.2 d
#
#      2022M05   2022M06   2022M07   2022M08   2022M09   2022M10  2022M11
# ...
