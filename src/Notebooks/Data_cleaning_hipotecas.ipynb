# %% [markdown]
# ## Dataset de hipotecas firmadas
# ### Viviendas, Número de hipotecas, total nacional.
# ### Unidades: hipotecas
#
# Fuente: Instituto Nacional de Estadística. Ref: HPT34618

# %%
# importaciones básicas
import numpy as np
import pandas as pd

# %%
hipotecas = pd.read_csv('../data/dataset7_hipotecas.csv', sep=';', encoding='utf-8' )
hipotecas.head(25)
# Out:
#                                               Column1    Column2      Column3  \
# 0                                     Datos de series        NaN          NaN
# 1                                                 NaN        NaN          NaN
# 2   Viviendas. Número de hipotecas. Total Nacional...        NaN          NaN
# 3                                               Serie   HPT34618          NaN
# 4                                        Periodicidad    Mensual          NaN
# 5                                              Unidad  Hipotecas          NaN
# 6                                               DATOS        NaN          NaN
# 7                                             PERIODO      VALOR    TIPO DATO
# 8                                             2022M10     41.022  Provisional
# 9                                             2022M09     44.119  Provisional
# 10                                            2022M08     36.721  Provisional
# ...

# %%
hipotecas.columns
# Out:
# Index(['Column1', 'Column2', 'Column3', 'Column4'], dtype='object')

# %%
hipotecas.drop(['Column3','Column4'], axis=1, inplace=True)

# %%
hipotecas
# Out:
#                                                Column1   Column2
# 0                                      Datos de series       NaN
# 1                                                  NaN       NaN
# 2    Viviendas. Número de hipotecas. Total Nacional...       NaN
# 3                                                Serie  HPT34618
# 4                                         Periodicidad   Mensual
# ..                                                 ...       ...
# 244                                            2003M02    88.381
# 245                                            2003M01    89.642
# 246                                                NaN       NaN
# 247                        Dato: .. Dato no disponible       NaN
# 248          Dato: . Protegido por secreto estadístico       NaN
#
# [249 rows x 2 columns]

# %%
hipotecas.drop([0,1,2,3,4,5,6],inplace=True)

# %%
hipotecas.reset_index(drop=True ,inplace=True)

# %%
hipotecas.columns = hipotecas.iloc[0]

# %%
hipotecas
# Out:
# 0                                      PERIODO   VALOR
# 0                                      PERIODO   VALOR
# 1                                      2022M10  41.022
# 2                                      2022M09  44.119
# 3                                      2022M08  36.721
# 4                                      2022M07  35.918
# ..                                         ...     ...
# 237                                    2003M02  88.381
# 238                                    2003M01  89.642
# 239                                        NaN     NaN
# 240                Dato: .. Dato no disponible     NaN
# 241  Dato: . Protegido por secreto estadístico     NaN
#
# [242 rows x 2 columns]

# %%
hipotecas.drop([0], inplace=True)

# %%
hipotecas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 241 entries, 1 to 241
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PERIODO  240 non-null    object
#  1   VALOR    238 non-null    object
# dtypes: object(2)
# memory usage: 13.8+ KB

# %%
hipotecas.dropna(thresh=1,inplace=True)

hipotecas.tail()
# Out:
# 0                                      PERIODO   VALOR
# 236                                    2003M03  85.577
# 237                                    2003M02  88.381
# 238                                    2003M01  89.642
# 240                Dato: .. Dato no disponible     NaN
# 241  Dato: . Protegido por secreto estadístico     NaN

# %%
hipotecas.drop([240,241], inplace=True)

# %%
hipotecas
# Out:
# 0    PERIODO   VALOR
# 1    2022M10  41.022
# 2    2022M09  44.119
# 3    2022M08  36.721
# 4    2022M07  35.918
# 5    2022M06  42.767
# ..       ...     ...
# 234  2003M05  86.628
# 235  2003M04  77.475
# 236  2003M03  85.577
# 237  2003M02  88.381
# 238  2003M01  89.642
#
# [238 rows x 2 columns]

# %%
hipotecas.rename(columns={'PERIODO':'periodo', 'VALOR': 'valor'}, inplace=True)

# %%
hipotecas
# Out:
# 0    periodo   valor
# 1    2022M10  41.022
# 2    2022M09  44.119
# 3    2022M08  36.721
# 4    2022M07  35.918
# 5    2022M06  42.767
# ..       ...     ...
# 234  2003M05  86.628
# 235  2003M04  77.475
# 236  2003M03  85.577
# 237  2003M02  88.381
# 238  2003M01  89.642
#
# [238 rows x 2 columns]

# %%
hipotecas.to_csv('../data/clean/hipotecas.csv', encoding='utf-8', index=False)
